# %%
import pandas as pd

# %%
housing = pd.read_csv('./datasets/chapter_2/housing.csv')

# %%
housing.head()
# Out:
#            id                                                url  \
# 0  7049044568  https://reno.craigslist.org/apa/d/reno-beautif...
# 1  7049047186  https://reno.craigslist.org/apa/d/reno-reduced...
# 2  7043634882  https://reno.craigslist.org/apa/d/sparks-state...
# 3  7049045324  https://reno.craigslist.org/apa/d/reno-1x1-fir...
# 4  7049043759  https://reno.craigslist.org/apa/d/reno-no-long...
#
#          region                   region_url  price       type  sqfeet  beds  \
# 0  reno / tahoe  https://reno.craigslist.org   1148  apartment    1078     3
# 1  reno / tahoe  https://reno.craigslist.org   1200      condo    1001     2
# 2  reno / tahoe  https://reno.craigslist.org   1813  apartment    1683     2
# 3  reno / tahoe  https://reno.craigslist.org   1095  apartment     708     1
# 4  reno / tahoe  https://reno.craigslist.org    289  apartment     250     0
#
#    baths  cats_allowed  ...  wheelchair_access  electric_vehicle_charge  \
# ...

# %%
housing['state'].value_counts()
il_housing = housing.query("state == 'il'")
print(il_housing.head())
# Out:
#                id                                                url  \
# 80254  7040982080  https://bn.craigslist.org/apa/d/bloomington-ca...
# 80295  7040683141  https://bn.craigslist.org/apa/d/bloomington-2-...
# 80444  7047015183  https://chambana.craigslist.org/apa/d/rantoul-...
# 80565  7048488813  https://chicago.craigslist.org/chc/apa/d/chica...
# 80767  7047353329  https://chicago.craigslist.org/chc/apa/d/chica...
#
#                    region                       region_url  price       type  \
# 80254  bloomington-normal        https://bn.craigslist.org    850  apartment
# 80295  bloomington-normal        https://bn.craigslist.org    625  apartment
# 80444    champaign urbana  https://chambana.craigslist.org    685  apartment
# 80565             chicago   https://chicago.craigslist.org   2910  apartment
# 80767             chicago   https://chicago.craigslist.org   2085       loft
#
#        sqfeet  beds  baths  cats_allowed  ...  wheelchair_access  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
il_housing.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'sqfeet'}>,
#         <AxesSubplot:title={'center':'beds'}>],
#        [<AxesSubplot:title={'center':'baths'}>,
#         <AxesSubplot:title={'center':'cats_allowed'}>,
#         <AxesSubplot:title={'center':'dogs_allowed'}>,
#         <AxesSubplot:title={'center':'smoking_allowed'}>],
#        [<AxesSubplot:title={'center':'wheelchair_access'}>,
#         <AxesSubplot:title={'center':'electric_vehicle_charge'}>,
#         <AxesSubplot:title={'center':'comes_furnished'}>,
#         <AxesSubplot:title={'center':'lat'}>],
#        [<AxesSubplot:title={'center':'long'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
il_housing.plot(kind='scatter', x='long', y='lat', alpha=0.4, s='sqfeet', label='square feet', c='price', cmap=plt.get_cmap('jet'), colorbar=True, figsize=(20, 15))
plt.legend()

# %%
correlation_matrix = il_housing.corr()

# %%
correlation_matrix['price'].sort_values(ascending=False)
# Out:
# price                      1.000000
# lat                        0.171489
# long                       0.155889
# id                         0.143211
# sqfeet                     0.135731
# baths                      0.131010
# comes_furnished            0.112352
# wheelchair_access          0.104965
# beds                       0.033606
# electric_vehicle_charge    0.018427
# dogs_allowed              -0.043698
# cats_allowed              -0.059470
# smoking_allowed           -0.144877
# Name: price, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['price', 'sqfeet', 'beds', 'baths', 'type']
scatter_matrix(il_housing[attributes], figsize=(15, 8))
# Out:
# array([[<AxesSubplot:xlabel='price', ylabel='price'>,
#         <AxesSubplot:xlabel='sqfeet', ylabel='price'>,
#         <AxesSubplot:xlabel='beds', ylabel='price'>,
#         <AxesSubplot:xlabel='baths', ylabel='price'>],
#        [<AxesSubplot:xlabel='price', ylabel='sqfeet'>,
#         <AxesSubplot:xlabel='sqfeet', ylabel='sqfeet'>,
#         <AxesSubplot:xlabel='beds', ylabel='sqfeet'>,
#         <AxesSubplot:xlabel='baths', ylabel='sqfeet'>],
#        [<AxesSubplot:xlabel='price', ylabel='beds'>,
#         <AxesSubplot:xlabel='sqfeet', ylabel='beds'>,
#         <AxesSubplot:xlabel='beds', ylabel='beds'>,
#         <AxesSubplot:xlabel='baths', ylabel='beds'>],
#        [<AxesSubplot:xlabel='price', ylabel='baths'>,
#         <AxesSubplot:xlabel='sqfeet', ylabel='baths'>,
#         <AxesSubplot:xlabel='beds', ylabel='baths'>,
#         <AxesSubplot:xlabel='baths', ylabel='baths'>]], dtype=object)

# %%
il_housing.plot(kind='scatter', x='sqfeet', y='price', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='sqfeet', ylabel='price'>

# %%
feature_cols = 'sqfeet'

X = il_housing[[feature_cols]]
y = il_housing['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predict = lin_model.predict(X_train)

# %%
import numpy as np
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_train, y_train_predict)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 545.2694711337621
# R2 score is 0.12595993530460992

# %%
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 1572.286249048053
# R2 score is -0.2290086751843976
